# %% [markdown]
# # Module importation

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# Evaluation
from sklearn.metrics import accuracy_score,classification_report

# %% [markdown]
# # Data Acquisation

# %%
data = pd.read_csv('diabetes dataset 1.csv')

data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.tail(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 758                     0.197   26        0
# 759                     0.278   66        1
# 760                     0.766   22        0
# ...

# %%
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# it shows the number of unique values in each column of dataframe

data.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
data.isna() # null values # nan
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## Data Visualisation

# %%
data.hist(figsize=(16,10))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Data Sampling

# %%
X = data.drop(columns="Outcome")
y = data.Outcome

print(X.shape)
print(y.shape)
# Out:
# (768, 8)
# (768,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

print("Taining data:",X_train.shape)
print("Testing data:",X_test.shape)
# Out:
# Taining data: (691, 8)
# Testing data: (77, 8)

# %% [markdown]
# ## Training KNN classifier

# %%
KNN = KNeighborsClassifier()
KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
KNN_predict = KNN.predict(X_test)

# %%
print(accuracy_score(y_test, KNN_predict))
# Out:
# 0.7922077922077922

# %%
print('accuracy',round(accuracy_score(y_test,KNN_predict)*100,4),'%')
print(classification_report(y_test,KNN_predict))
# Out:
# accuracy 79.2208 %
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84        52
#            1       0.67      0.72      0.69        25
#
#     accuracy                           0.79        77
#    macro avg       0.76      0.77      0.77        77
# weighted avg       0.80      0.79      0.79        77

# %% [markdown]
# ## Random forest classifier

# %%
RF = RandomForestClassifier()
RF.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
RF_predict = RF.predict(X_test)

# %%
print(accuracy_score(y_test, RF_predict))
# Out:
# 0.7142857142857143

# %%
print('accuracy',round(accuracy_score(y_test,RF_predict)*100,4),'%')
print(classification_report(y_test,RF_predict))
# Out:
# accuracy 71.4286 %
#               precision    recall  f1-score   support
#
#            0       0.81      0.75      0.78        52
#            1       0.55      0.64      0.59        25
#
#     accuracy                           0.71        77
#    macro avg       0.68      0.70      0.69        77
# weighted avg       0.73      0.71      0.72        77

# %% [markdown]
# ## Decision tree

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred = dt.predict(X_test)

# %%
accuracy_score(y_test,dt_pred)
# Out:
# 0.6883116883116883

# %% [markdown]
# # pip install seaborn

# %%
import seaborn as sns

algorithms = ['KNN', 'Random forest', "Decision Tree"]
Accuracy = [(round(accuracy_score(y_test,KNN_predict)*100,4)),(round(accuracy_score(y_test,RF_predict)*100,4)),(round(accuracy_score(y_test,dt_pred)*100,4))]
print(Accuracy)

accplot = sns.barplot(x=algorithms, y=Accuracy)
accplot.set_ylim(65, 80)
accplot.set_title("Accuracy Comparison")
accplot.set_xlabel("Models")
accplot.set_ylabel("Accuracy")
# Out:
# [79.2208, 71.4286, 68.8312]
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# Text(0, 0.5, 'Accuracy')

# %% [markdown]
# # kaggle

# %% [markdown]
# ## Saving the best model

# %%
import pickle

pickle.dump(KNN,open("Diabetes_model.pkl","wb"))

# %% [markdown]
# ## Inference

# %%
# Pregnancies	Glucose	BloodPressure	SkinThickness	Insulin	BMI	DiabetesPedigreeFunction	Age
def Predict_Diabetic_patient(input):
    loaded_model = pickle.load(open("Diabetes_model.pkl","rb"))

    prediction = loaded_model.predict([input])
    if prediction[0] == 1:
        return "Diabetic Patient"
    else:
        return "Non Diabetic Patient"


Predict_Diabetic_patient([6,148,72,35,0,33.6,0.627,50])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'Diabetic Patient'

# %%
Predict_Diabetic_patient([0,1,6,2,0,0,0,1])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# 'Non Diabetic Patient'
